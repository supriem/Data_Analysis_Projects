# %%
#im porting necessary packages
# %pylab inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#reading the CSV file from PC
data=pd.read_csv('/home/suprim/Desktop/uber-raw-data-apr14.csv')

# %%
# Start exploring the dataset
print(data.columns)
# Out:
# Index(['Date/Time', 'Lat', 'Lon', 'Base', 'dom', 'weekday'], dtype='object')

# %%
data  #shows rows and columns of data
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1         4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2         4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3         4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4         4/1/2014 0:33:00  40.7594 -73.9722  B02512
# 5         4/1/2014 0:33:00  40.7383 -74.0403  B02512
# 6         4/1/2014 0:39:00  40.7223 -73.9887  B02512
# 7         4/1/2014 0:45:00  40.7620 -73.9790  B02512
# 8         4/1/2014 0:55:00  40.7524 -73.9960  B02512
# 9         4/1/2014 1:01:00  40.7575 -73.9846  B02512
# 10        4/1/2014 1:19:00  40.7256 -73.9869  B02512
# 11        4/1/2014 1:48:00  40.7591 -73.9684  B02512
# 12        4/1/2014 1:49:00  40.7271 -73.9803  B02512
# 13        4/1/2014 2:11:00  40.6463 -73.7896  B02512
# 14        4/1/2014 2:25:00  40.7564 -73.9167  B02512
# 15        4/1/2014 2:31:00  40.7666 -73.9531  B02512
# 16        4/1/2014 2:43:00  40.7580 -73.9761  B02512
# ...

# %%
data.head()  #gives  1st 5 data
# Out:
#           Date/Time      Lat      Lon    Base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512

# %%
data.tail()  #gives last 5data
# Out:
#                  Date/Time      Lat      Lon    Base
# 564511  4/30/2014 23:22:00  40.7640 -73.9744  B02764
# 564512  4/30/2014 23:26:00  40.7629 -73.9672  B02764
# 564513  4/30/2014 23:31:00  40.7443 -73.9889  B02764
# 564514  4/30/2014 23:32:00  40.6756 -73.9405  B02764
# 564515  4/30/2014 23:48:00  40.6880 -73.9608  B02764

# %%
print(data.shape)  #gives total no of data
# Out:
# (564516, 4)

# %%
#since this is huge dataset so we are taking 10% for analysis purpose
data = data.sample(frac=0.1, random_state = 1)
print(data.shape)          #total row vs columns of data
print(data.describe())
# Out:
# (5645, 6)
#                Lat          Lon          dom
# count  5645.000000  5645.000000  5645.000000
# mean     40.740372   -73.977425    16.150753
# std       0.036720     0.051703     9.017766
# min      40.556000   -74.449400     1.000000
# 25%      40.722500   -73.998000     8.000000
# 50%      40.743300   -73.985300    16.000000
# 75%      40.760800   -73.970100    24.000000
# max      41.120000   -73.202300    30.000000

# %% [markdown]
# #  Date and Time Tweak

# %%
dt='4/30/2014 23:22:00'

# %%
dt=pd.to_datetime(dt)

# %%
dt
# Out:
# Timestamp('2014-04-30 23:22:00')

# %%
dt.weekday()
# Out:
# 2

# %%
dt.day_name
# Out:
# <bound method Timestamp.day_name of Timestamp('2014-04-30 23:22:00')>

# %%
data['Date/Time']=data['Date/Time'].map(pd.to_datetime)

# %%
def get_dom(dt):
    return dt.day
data['dom']=data['Date/Time'].map(get_dom)

# %%
dt=data['Date/Time'][500000]

# %%
dt.day
# Out:
# 24

# %%
def get_weekday(dt):
    return dt.weekday
data['weekday']=data['Date/Time'].map(get_weekday)
data.tail()
# Out:
#                  Date/Time      Lat      Lon    Base  dom  \
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764   30
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764   30
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764   30
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764   30
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764   30
#
#                                                   weekday
# 564511  <built-in method weekday of Timestamp object a...
# 564512  <built-in method weekday of Timestamp object a...
# 564513  <built-in method weekday of Timestamp object a...
# 564514  <built-in method weekday of Timestamp object a...
# 564515  <built-in method weekday of Timestamp object a...

# %% [markdown]
# # ANALYSIS

# %% [markdown]
# Analyzing the DOM

# %% [markdown]
# # Plotting Histograms

# %%
# Plot histograms of each parameter  
data.hist(figsize = (20, 20))  #we have 3 parameters LAT LON and DOM
plt.show()

# %%
hist(data.dom,bins=30)
# Out:
# (array([14546., 17474., 20701., 26714., 19521., 13445., 19550., 16188.,
#         16843., 20041., 20420., 18170., 12112., 12674., 20641., 17717.,
#         20973., 18074., 14602., 11017., 13162., 16975., 20346., 23352.,
#         25095., 24925., 14677., 15475., 22835., 36251.]),
#  array([ 1.        ,  1.96666667,  2.93333333,  3.9       ,  4.86666667,
#          5.83333333,  6.8       ,  7.76666667,  8.73333333,  9.7       ,
#         10.66666667, 11.63333333, 12.6       , 13.56666667, 14.53333333,
#         15.5       , 16.46666667, 17.43333333, 18.4       , 19.36666667,
#         20.33333333, 21.3       , 22.26666667, 23.23333333, 24.2       ,
#         25.16666667, 26.13333333, 27.1       , 28.06666667, 29.03333333,
#         30.        ]),
#  <a list of 30 Patch objects>)

# %%
hist(data.dom,bins=30,rwidth=0.8, range=(0.5,30.5))
xlabel('date of the month')
ylabel('frequency')
title('Frequency by DOM')
# Out:
# Text(0.5, 1.0, 'Frequency by DOM')

# %%
for k,rows in data.groupby('dom'):
    print(k,rows)
# Out:
# 1                  Date/Time      Lat      Lon    Base  dom  \
# 0      2014-04-01 00:11:00  40.7690 -73.9549  B02512    1
# 1      2014-04-01 00:17:00  40.7267 -74.0345  B02512    1
# 2      2014-04-01 00:21:00  40.7316 -73.9873  B02512    1
# 3      2014-04-01 00:28:00  40.7588 -73.9776  B02512    1
# 4      2014-04-01 00:33:00  40.7594 -73.9722  B02512    1
# 5      2014-04-01 00:33:00  40.7383 -74.0403  B02512    1
# 6      2014-04-01 00:39:00  40.7223 -73.9887  B02512    1
# 7      2014-04-01 00:45:00  40.7620 -73.9790  B02512    1
# 8      2014-04-01 00:55:00  40.7524 -73.9960  B02512    1
# 9      2014-04-01 01:01:00  40.7575 -73.9846  B02512    1
# 10     2014-04-01 01:19:00  40.7256 -73.9869  B02512    1
# 11     2014-04-01 01:48:00  40.7591 -73.9684  B02512    1
# 12     2014-04-01 01:49:00  40.7271 -73.9803  B02512    1
# 13     2014-04-01 02:11:00  40.6463 -73.7896  B02512    1
# 14     2014-04-01 02:25:00  40.7564 -73.9167  B02512    1
# ...

# %%
def count_rows(rows):
    return len(rows)
by_date=data.groupby('dom').apply(count_rows)
by_date
# Out:
# dom
# 1     14546
# 2     17474
# 3     20701
# 4     26714
# 5     19521
# 6     13445
# 7     19550
# 8     16188
# 9     16843
# 10    20041
# 11    20420
# 12    18170
# 13    12112
# 14    12674
# 15    20641
# 16    17717
# 17    20973
# 18    18074
# 19    14602
# 20    11017
# 21    13162
# 22    16975
# 23    20346
# 24    23352
# 25    25095
# 26    24925
# 27    14677
# 28    15475
# 29    22835
# 30    36251
# dtype: int64

# %% [markdown]
# No of record per day of the month

# %%
plot(by_date)

# %%
bar(range(1,31),by_date)
# Out:
# <BarContainer object of 30 artists>

# %%
by_date_sorted=by_date.sort_values() #sorts value with resp to date
by_date_sorted
# Out:
# dom
# 20    11017
# 13    12112
# 14    12674
# 21    13162
# 6     13445
# 1     14546
# 19    14602
# 27    14677
# 28    15475
# 8     16188
# 9     16843
# 22    16975
# 2     17474
# 16    17717
# 18    18074
# 12    18170
# 5     19521
# 7     19550
# 10    20041
# 23    20346
# 11    20420
# 15    20641
# 3     20701
# 17    20973
# 29    22835
# 24    23352
# 26    24925
# 25    25095
# 4     26714
# 30    36251
# dtype: int64

# %%
bar(range(1,31),by_date_sorted)
# Out:
# <BarContainer object of 30 artists>

# %% [markdown]
# # Analyzing Hour

# %%
hist(data.hour,bins=24,range=(.5,24))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-3bdede153f4f> in <module>
#       1
# ----> 2 hist(data.hour,bins=24,range=(.5,24))
#
# ~/anaconda3/envs/m_l/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'hour'

# %%
hist(data.weekday,bins=7,range=(.5,7),rwidth=.8,color='green')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-79a6792ff8c8> in <module>
# ----> 1 hist(data.weekday,bins=7,range=(.5,7),rwidth=.8,color='green')
#
# ~/anaconda3/envs/m_l/lib/python3.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2659         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2660         color=color, label=label, stacked=stacked, normed=normed,
# -> 2661         **({"data": data} if data is not None else {}), **kwargs)
#    2662
#    2663
#
# ~/anaconda3/envs/m_l/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %% [markdown]
# # By Latitude & Longitude

# %%
hist(data['Lat'])
# Out:
# (array([8.00000e+00, 3.20000e+01, 3.74460e+04, 5.25371e+05, 1.57200e+03,
#         7.60000e+01, 8.00000e+00, 2.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([40.0729 , 40.27727, 40.48164, 40.68601, 40.89038, 41.09475,
#         41.29912, 41.50349, 41.70786, 41.91223, 42.1166 ]),
#  <a list of 10 Patch objects>)
